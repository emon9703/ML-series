# %%
import numpy as np
import pandas as pd
import seaborn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('cardio_train.csv',sep=';')

# %%
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
data.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
data['age_year'] = (data['age']/365).round(0)

# %%
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  age_year
# ...

# %%
data = data.drop(columns=['age', 'id'])

# %%
data
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio  age_year
# ...

# %%
seaborn.countplot(x = 'cardio', data=data)
# Out:
# <Axes: xlabel='cardio', ylabel='count'>

# %%
data['gender'] = data['gender'].astype(str)
data['cardio'] = data['cardio'].astype(str)
seaborn.countplot(x='gender', hue='cardio', data=data)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
data['smoke'] = data['smoke'].astype(str)
data['cardio'] = data['cardio'].astype(str)
seaborn.countplot(x='smoke', hue='cardio', data=data)
# Out:
# <Axes: xlabel='smoke', ylabel='count'>

# %%
x = data.drop(['cardio'], axis=1)

# %%
x
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  age_year
# 0           1      50.0
# ...

# %%
y = data['cardio']

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=11)

# %%
xtrain
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 60991       1     165    65.0    120     80            1     1      0     0
# 24355       2     156    50.0    110     70            1     1      0     0
# 40247       2     175    95.0    130     80            1     1      0     0
# 43969       1     165    65.0    110     58            1     1      0     0
# 48058       1     169    80.0    150     90            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 30369       2     175    99.0    190   1000            2     1      0     0
# 57676       1     153    56.0    110     70            1     1      0     0
# 21584       1     170    78.0    120     80            3     3      0     0
# 36543       1     160    70.0    110     70            1     1      0     0
# 10137       2     172    57.0    130     90            3     3      0     0
#
#        active  age_year
# 60991       1      58.0
# ...

# %%
ytrain
# Out:
# 60991    0
# 24355    1
# 40247    0
# 43969    1
# 48058    1
#         ..
# 30369    1
# 57676    0
# 21584    1
# 36543    1
# 10137    1
# Name: cardio, Length: 49000, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rclf = RandomForestClassifier()

# %%
Rclf.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier()

# %%
Rclf.score(xtest, ytest)
# Out:
# 0.7107142857142857
